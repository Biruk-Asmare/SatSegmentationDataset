# %%
import pandas as pd
import glob

# %%
all_labled_json=glob.glob("*.json")

# %%
len(all_labled_json)
# Out:
# 1437

# %%
import random
random.shuffle(all_labled_json)

# %%
0.15*1437
# Out:
# 215.54999999999998

# %%
train=all_labled_json[0:1000]
val=all_labled_json[1000:1214]
test=all_labled_json[1214:1436]

# %%
len(train)
# Out:
# 1000

# %%
len(test)
# Out:
# 222

# %%
len(val)
# Out:
# 214

# %%
import shutil
for tf in train:
    shutil.copy2(tf, "./labels/train")
    print(tf)
# Out:
# 7121_2019-12-10T10_15_50.907Z_24_features.json
# 6141_2019-03-22T10_57_54.503Z_4_features.json
# 43825_2019-04-18T11_00_34.375Z_5_features.json
# 5944_2019-04-12T09_42_53.793Z_4_features.json
# 8303_2019-10-23T10_03_03.671Z_12_features.json
# 5791_2019-10-22T09_47_29.916Z_15_features.json
# 46405_2019-06-14T10_35_45.858Z_10_features.json
# 9486_2019-02-07T11_36_27.459Z_2_features.json
# 5120_2019-11-07T10_06_45.064Z_31_features.json
# 74662_2019-05-19T10_16_31.831Z_16_features.json
# 9704_2019-11-06T09_47_16.437Z_16_features.json
# 412_2019-09-29T10_28_32.759Z_18_features.json
# 6494_2019-02-17T09_56_41.219Z_0_features.json
# 43604_2019-05-13T10_46_26.332Z_5_features.json
# 44791_2019-07-24T10_36_46.579Z_13_features.json
# 6594_2019-06-16T10_22_24.798Z_25_features.json
# 202237_2019-07-08T10_17_00.504Z_13_features.json
# 44791_2019-12-04T10_46_29.765Z_23_features.json
# 44791_2019-09-20T10_46_35.773Z_19_features.json
# 46984_2019-06-13T10_16_46.233Z_19_features.json
# ...

# %%
for f in val:
    shutil.copy2(f, "./labels/validate")
    print(f)
# Out:
# 9704_2019-02-19T09_47_15.965Z_0_features.json
# 73639_2019-05-12T10_26_48.468Z_10_features.json
# 43825_2019-01-18T10_46_36.633Z_0_features.json
# 7121_2019-06-13T10_15_57.500Z_11_features.json
# 46848_2019-04-22T10_30_33.139Z_7_features.json
# 167657_2019-08-13T11_26_19.537Z_10_features.json
# 3124_2019-03-21T10_43_14.938Z_4_features.json
# 15796_2019-08-19T09_18_50.668Z_15_features.json
# 43866_2019-12-04T10_46_30.890Z_11_features.json
# 20180_2019-11-30T10_15_53.534Z_36_features.json
# 5942_2019-08-23T09_44_01.090Z_15_features.json
# 19_2019-03-06T09_49_11.175Z_0_features.json
# 16070_2019-10-16T10_17_07.006Z_37_features.json
# 6493_2019-11-01T09_46_50.317Z_7_features.json
# 46405_2019-01-05T10_35_36.777Z_0_features.json
# 4663_2019-02-19T09_46_46.695Z_1_features.json
# 198_2019-03-20T10_29_41.074Z_6_features.json
# 73639_2019-11-10T10_16_45.616Z_11_features.json
# 43604_2019-08-26T10_46_27Z_8_features.json
# 6306_2019-02-20T10_56_40.788Z_4_features.json
# ...

# %%
for f in test:
    shutil.copy2(f, "./labels/test")
    print(f)
# Out:
# 46361_2019-12-20T10_16_17.169Z_14_features.json
# 15796_2019-09-03T09_18_44.998Z_17_features.json
# 74579_2019-09-26T10_16_43.189Z_13_features.json
# 7049_2019-09-10T09_53_34.761Z_20_features.json
# 46848_2019-01-22T10_26_25.707Z_1_features.json
# 7049_2019-04-28T09_53_37.116Z_10_features.json
# 5942_2019-09-02T09_43_59.311Z_18_features.json
# 7049_2019-04-05T09_47_35.557Z_7_features.json
# 16070_2019-01-19T10_17_05.579Z_0_features.json
# 44791_2019-09-10T10_46_34.254Z_18_features.json
# 6085_2019-04-07T09_38_10.888Z_3_features.json
# 412_2019-07-21T10_28_41.059Z_12_features.json
# 5120_2019-09-15T09_56_45.687Z_25_features.json
# 8303_2019-02-17T09_53_02.301Z_2_features.json
# 468_2019-03-26T09_53_39.378Z_6_features.json
# 10003_2019-02-20T10_56_40.788Z_1_features.json
# 1298_2019-08-26T09_56_32.205Z_13_features.json
# 300045_2019-03-06T09_50_28.797Z_5_features.json
# 6141_2019-02-03T11_06_52.316Z_3_features.json
# 15796_2019-04-01T09_25_04.543Z_6_features.json
# ...
